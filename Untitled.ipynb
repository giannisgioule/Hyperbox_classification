# %%
from math import *
from pyomo.environ import *
from pyomo.opt import SolverFactory
import sys
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

dataset=pd.read_csv("C:/Users/Ioannis/Desktop/Datasets/Classification/Compound.csv")

number_predictors=dataset.shape[1]-1 # The number of predictors in the set
attribute_names=dataset.columns[0:number_predictors]
X=dataset.iloc[:,0:number_predictors]
# Y=dataset.iloc[:,(dataset.shape[1]-1)]

#=================================================
# Define the scaler function and scale the input
# variables
#=================================================
scaler=MinMaxScaler()
scaler.fit(X)
std_X=scaler.transform(X)
# Define it as a pandas DataFrame to work with 
# the gdxpds library
std_X=pd.DataFrame(std_X)
#=================================================

# Change the column names to match original data
std_X.columns=attribute_names
dataset.iloc[:,0:number_predictors]=std_X

target=dataset.iloc[:,len(dataset.columns)-1]

X_train,X_test,y_train,y_test=train_test_split(dataset,target,test_size=0.7,random_state=50)
y_test=list(map(str,y_test))

def generate(dataset):
        number_predictors=dataset.shape[1]-1 # The number of predictors in the set
        attribute_names=dataset.columns[0:number_predictors] # The names of the attributes        

        # Create the set of samples
        s_val=list(range(1, dataset.shape[0]+1))
        s_val=list(map(str,s_val))
        s_val=["s"+x for x in s_val]
        s=s_val
        m=attribute_names
        boxes=list(np.unique(dataset['class']))

        s_val=s_val*number_predictors
        s_val=pd.DataFrame(s_val)

        values=dataset.iloc[:,0:number_predictors]
        values=values.unstack()
        values=pd.DataFrame(list(values))

        all_attr=pd.DataFrame(np.repeat(attribute_names[0],dataset.shape[0]))
        for i in range(1,number_predictors):
                single_attr=pd.DataFrame(np.repeat(attribute_names[i],dataset.shape[0]))
                all_attr=pd.concat([all_attr,single_attr],axis=0)                

        all_attr.index=s_val.index
        final_values=pd.concat([s_val,all_attr],axis=1)
        final_values=pd.concat([final_values,values],axis=1)
        del(values)

        dataset.index=s_val[0:dataset.shape[0]].index
        www=pd.concat([s_val[0:dataset.shape[0]],dataset.iloc[:,number_predictors]],axis=1)

        A={}    
        mapping={}
        for i in range(final_values.shape[0]):
                A.update({tuple(final_values.iloc[i,0:2]):final_values.iloc[i,2]})
        for i in range(www.shape[0]):
                mapping.update({tuple(www.iloc[i,:]):1})

        data={None:{
        'i':{None:boxes},
        'm':{None:m},
        's':{None:s},
        'A':A,
        'map':mapping
        }}

        return data

data=generate(X_train)

model=AbstractModel()

#======================================================
#			 Define the model sets
#======================================================
model.s=Set(dimen=1,doc='Samples')
model.m=Set(dimen=1,doc='Features')
model.i=Set(dimen=1,doc='Boxes')
model.j=SetOf(model.i)
#======================================================

#======================================================
#	 Define the model parameters and variables
#======================================================
# Parameters
model.A=Param(model.s,model.m,doc='Value of sample s on attribute m')
model.U=Param(initialize=1.5)
model.map=Param(model.s,model.i,doc='Mapping',default=0)

# Variables
model.x=Var(model.i,model.m,domain=Reals)
model.LE=Var(model.i,model.m,domain=Reals)

model.E=Var(model.s,domain=Binary)
model.Y=Var(model.i,model.j,model.m,domain=Binary)
#======================================================

def objective(model):
        objective_value=sum(1-model.E[s] for s in model.s)
        return objective_value
model.OBJ=Objective(rule=objective,sense=minimize)

def enclosing_1(model,i,s,m):
        if(model.map[s,i]==1):
                return model.A[s,m]>=model.x[i,m]-(model.LE[i,m]/2)-model.U*(1-model.E[s])
        else:
                return Constraint.Skip
model.eq1=Constraint(model.i,model.s,model.m,rule=enclosing_1)

def enclosing_2(model,i,s,m):
        if(model.map[s,i]==1):
                return model.A[s,m]<=model.x[i,m]+(model.LE[i,m]/2)+model.U*(1-model.E[s])
        else:
                return Constraint.Skip
model.eq2=Constraint(model.i,model.s,model.m,rule=enclosing_2)

def non_overlap_1(model,m,i,j):
        if(i!=j):
                return model.x[i,m]-model.x[j,m]+model.U*model.Y[i,j,m]>=(model.LE[i,m]+model.LE[j,m])/2+0.001
        else:
                return Constraint.Skip
model.eq3=Constraint(model.m,model.i,model.j,rule=non_overlap_1)

def non_overlap_2(model,i,j):
        if(i<len(model.i) and j>=i+1):
                return sum(model.Y[i,j,m]+model.Y[j,i,m] for m in model.m)<=2*len(model.m)-1
        else:
                return Constraint.Skip
model.eq4=Constraint(model.i,model.j,rule=non_overlap_2)

def pyomo_postprocess(options=None, instance=None, results=None):
  model.x.display()
  

opt=SolverFactory('cplex')
opt.options['mipgap']=0
instance=model.create_instance(data)
results=opt.solve(instance,tee=True)
results.write()
# pyomo_postprocess(None, instance, results)

i=model.create_instance(data)
i.pprint()
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 12.8.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2017.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\Ioannis\AppData\Local\Temp\tmpotecenoo.cplex.log' open.
# CPLEX> Problem 'C:\Users\Ioannis\AppData\Local\Temp\tmpewko6jcj.pyomo.lp' read.
# Read time = 0.00 sec. (0.04 ticks)
# CPLEX> Problem name         : C:\Users\Ioannis\AppData\Local\Temp\tmpewko6jcj.pyomo.lp
# Objective sense      : Minimize
# Variables            :     160  [Nneg: 1,  Free: 16,  Binary: 143]
# Objective nonzeros   :     120
# Linear constraints   :     507  [Less: 268,  Greater: 238,  Equal: 1]
#   Nonzeros           :    1573
#   RHS nonzeros       :     507
#
# Variables            : Min LB: 0.0000000        Max UB: 1.000000
# Objective nonzeros   : Min   : 1.000000         Max   : 119.0000
# Linear constraints   :
#   Nonzeros           : Min   : 0.5000000        Max   : 1.500000
#   RHS nonzeros       : Min   : 0.001000000      Max   : 3.000000
# CPLEX> Tried aggregator 1 time.
# MIP Presolve eliminated 1 rows and 1 columns.
# Reduced MIP has 506 rows, 159 columns, and 1572 nonzeros.
# Reduced MIP has 143 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.54 ticks)
# Found incumbent of value 119.000000 after 0.02 sec. (1.00 ticks)
# Probing time = 0.00 sec. (0.04 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 506 rows, 159 columns, and 1572 nonzeros.
# Reduced MIP has 143 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.69 ticks)
# Probing time = 0.00 sec. (0.04 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 12 threads.
# Root relaxation solution time = 0.00 sec. (1.23 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          119.0000        0.0000           100.00%
#       0     0        0.0000     2      119.0000        0.0000       46  100.00%
# *     0+    0                            0.0000        0.0000             0.00%
#       0     0        cutoff              0.0000        0.0000       46    0.00%
# Elapsed time = 0.02 sec. (4.75 ticks, tree = 0.01 MB, solutions = 2)
#
# Root node processing (before b&c):
#   Real time             =    0.03 sec. (4.76 ticks)
# Parallel b&c, 12 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.03 sec. (4.76 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  0.0000000000e+00
# Solution time =    0.03 sec.  Iterations = 46  Nodes = 0
# Deterministic time = 4.76 ticks  (148.86 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\Ioannis\AppData\Local\Temp\tmphwdqx_i7.cplex.sol'.
# CPLEX> # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: tmpewko6jcj
#   Lower bound: 0.0
#   Upper bound: 0.0
#   Number of objectives: 1
#   Number of constraints: 507
#   Number of variables: 160
#   Number of nonzeros: 1573
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   User time: 0.03
#   Termination condition: optimal
#   Termination message: MIP - Integer optimal solution\x3a Objective = 0.0000000000e+00
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.07390689849853516
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 17 Set Declarations
#     A_index : Dim=0, Dimen=2, Size=238, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     LE_index : Dim=0, Dimen=2, Size=8, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     Y_index : Dim=0, Dimen=3, Size=32, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     Y_index_index_0 : Dim=0, Dimen=2, Size=32, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq1_index : Dim=0, Dimen=3, Size=952, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq1_index_index_0 : Dim=0, Dimen=2, Size=952, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq2_index : Dim=0, Dimen=3, Size=952, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq2_index_index_0 : Dim=0, Dimen=2, Size=952, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq3_index : Dim=0, Dimen=3, Size=32, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq3_index_index_0 : Dim=0, Dimen=2, Size=32, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     eq4_index : Dim=0, Dimen=2, Size=16, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     i : Boxes
#         Dim=0, Dimen=1, Size=4, Domain=None, Ordered=False, Bounds=(1, 4)
#         [1, 2, 3, 4]
#     j : Dim=0, Dimen=1, Size=4, Domain=None, Ordered=False, Bounds=(None, None)
#         [1, 2, 3, 4]
#     m : Features
#         Dim=0, Dimen=1, Size=2, Domain=None, Ordered=False, Bounds=None
#         ['x1', 'x2']
#     map_index : Dim=0, Dimen=2, Size=476, Domain=None, Ordered=False, Bounds=None
#         Virtual
#     s : Samples
#         Dim=0, Dimen=1, Size=119, Domain=None, Ordered=False, Bounds=None
#         ['s1', 's10', 's100', 's101', 's102', 's103', 's104', 's105', 's106', 's107', 's108', 's109', 's11', 's110', 's111', 's112', 's113', 's114', 's115', 's116', 's117', 's118', 's119', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's2', 's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's3', 's30', 's31', 's32', 's33', 's34', 's35', 's36', 's37', 's38', 's39', 's4', 's40', 's41', 's42', 's43', 's44', 's45', 's46', 's47', 's48', 's49', 's5', 's50', 's51', 's52', 's53', 's54', 's55', 's56', 's57', 's58', 's59', 's6', 's60', 's61', 's62', 's63', 's64', 's65', 's66', 's67', 's68', 's69', 's7', 's70', 's71', 's72', 's73', 's74', 's75', 's76', 's77', 's78', 's79', 's8', 's80', 's81', 's82', 's83', 's84', 's85', 's86', 's87', 's88', 's89', 's9', 's90', 's91', 's92', 's93', 's94', 's95', 's96', 's97', 's98', 's99']
#     x_index : Dim=0, Dimen=2, Size=8, Domain=None, Ordered=False, Bounds=None
#         Virtual
#
# 3 Param Declarations
#     A : Value of sample s on attribute m
#         Size=238, Index=A_index, Domain=Any, Default=None, Mutable=False
#         Key            : Value
#           ('s1', 'x1') :  0.09790209790209792
#           ('s1', 'x2') :  0.22352941176470587
#          ('s10', 'x1') :  0.14125874125874122
#          ('s10', 'x2') :  0.07352941176470584
#         ('s100', 'x1') :   0.0811188811188811
#         ('s100', 'x2') :   0.5970588235294118
#         ('s101', 'x1') :   0.7384615384615383
#         ('s101', 'x2') :   0.6382352941176471
#         ('s102', 'x1') :   0.3328671328671328
#         ('s102', 'x2') :  0.09999999999999998
#         ('s103', 'x1') :   0.1048951048951049
#         ('s103', 'x2') :   0.9764705882352941
#          ('s89', 'x2') :   0.6441176470588235
#           ('s9', 'x1') :   0.6881118881118882
#           ('s9', 'x2') :    0.526470588235294
#          ('s90', 'x1') :  0.03916083916083918
#          ('s90', 'x2') :   0.8382352941176471
#          ('s91', 'x1') :   0.5748251748251747
#          ('s91', 'x2') :   0.8882352941176471
#          ('s92', 'x1') :  0.27272727272727265
#          ('s92', 'x2') :                 0.35
#          ('s93', 'x1') :   0.7594405594405593
#          ('s93', 'x2') :   0.5352941176470588
#          ('s94', 'x1') :  0.32027972027972035
#          ('s94', 'x2') :   0.3676470588235293
#          ('s95', 'x1') :                  1.0
#          ('s95', 'x2') :  0.32352941176470584
#          ('s96', 'x1') :   0.1944055944055944
#          ('s96', 'x2') :                 0.35
#          ('s97', 'x1') :    0.220979020979021
#          ('s97', 'x2') :   0.3411764705882353
#          ('s98', 'x1') :   0.8531468531468531
#          ('s98', 'x2') :    0.626470588235294
#          ('s99', 'x1') :  0.37202797202797194
#          ('s99', 'x2') :   0.9999999999999999
#     U : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :   1.5
#     map : Mapping
#         Size=476, Index=map_index, Domain=Any, Default=0, Mutable=False
#         Key         : Value
#           ('s1', 4) :     1
#          ('s10', 4) :     1
#         ('s100', 2) :     1
#         ('s101', 1) :     1
#         ('s102', 4) :     1
#         ('s103', 2) :     1
#         ('s104', 4) :     1
#         ('s105', 1) :     1
#         ('s106', 4) :     1
#         ('s107', 1) :     1
#         ('s108', 4) :     1
#         ('s109', 1) :     1
#          ('s11', 4) :     1
#         ('s110', 4) :     1
#         ('s111', 4) :     1
#         ('s112', 4) :     1
#         ('s113', 4) :     1
#         ('s114', 1) :     1
#         ('s115', 1) :     1
#         ('s116', 4) :     1
#         ('s117', 1) :     1
#         ('s118', 4) :     1
#         ('s119', 2) :     1
#          ('s12', 4) :     1
#          ('s13', 4) :     1
#          ('s14', 1) :     1
#          ('s15', 4) :     1
#          ('s16', 1) :     1
#          ('s17', 2) :     1
#          ('s18', 4) :     1
#          ('s19', 4) :     1
#           ('s2', 1) :     1
#          ('s20', 4) :     1
#          ('s21', 1) :     1
#          ('s22', 4) :     1
#          ('s23', 1) :     1
#          ('s24', 1) :     1
#          ('s25', 4) :     1
#          ('s26', 4) :     1
#          ('s27', 1) :     1
#          ('s28', 2) :     1
#          ('s29', 4) :     1
#           ('s3', 4) :     1
#          ('s30', 1) :     1
#          ('s31', 4) :     1
#          ('s32', 2) :     1
#          ('s33', 4) :     1
#          ('s34', 4) :     1
#          ('s35', 3) :     1
#          ('s36', 4) :     1
#          ('s37', 4) :     1
#          ('s38', 1) :     1
#          ('s39', 1) :     1
#           ('s4', 4) :     1
#          ('s40', 4) :     1
#          ('s41', 4) :     1
#          ('s42', 4) :     1
#          ('s43', 2) :     1
#          ('s44', 4) :     1
#          ('s45', 4) :     1
#          ('s46', 1) :     1
#          ('s47', 3) :     1
#          ('s48', 1) :     1
#          ('s49', 4) :     1
#           ('s5', 1) :     1
#          ('s50', 4) :     1
#          ('s51', 1) :     1
#          ('s52', 4) :     1
#          ('s53', 4) :     1
#          ('s54', 4) :     1
#          ('s55', 3) :     1
#          ('s56', 3) :     1
#          ('s57', 1) :     1
#          ('s58', 4) :     1
#          ('s59', 3) :     1
#           ('s6', 1) :     1
#          ('s60', 4) :     1
#          ('s61', 3) :     1
#          ('s62', 1) :     1
#          ('s63', 4) :     1
#          ('s64', 1) :     1
#          ('s65', 3) :     1
#          ('s66', 1) :     1
#          ('s67', 2) :     1
#          ('s68', 4) :     1
#          ('s69', 2) :     1
#           ('s7', 1) :     1
#          ('s70', 2) :     1
#          ('s71', 1) :     1
#          ('s72', 4) :     1
#          ('s73', 4) :     1
#          ('s74', 1) :     1
#          ('s75', 4) :     1
#          ('s76', 1) :     1
#          ('s77', 3) :     1
#          ('s78', 1) :     1
#          ('s79', 1) :     1
#           ('s8', 4) :     1
#          ('s80', 1) :     1
#          ('s81', 4) :     1
#          ('s82', 4) :     1
#          ('s83', 4) :     1
#          ('s84', 4) :     1
#          ('s85', 1) :     1
#          ('s86', 1) :     1
#          ('s87', 1) :     1
#          ('s88', 1) :     1
#          ('s89', 1) :     1
#           ('s9', 1) :     1
#          ('s90', 2) :     1
#          ('s91', 1) :     1
#          ('s92', 4) :     1
#          ('s93', 1) :     1
#          ('s94', 4) :     1
#          ('s95', 1) :     1
#          ('s96', 4) :     1
#          ('s97', 4) :     1
#          ('s98', 1) :     1
#          ('s99', 3) :     1
#
# 4 Var Declarations
#     E : Size=119, Index=s
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#           s1 :     0 :  None :     1 : False :  True : Binary
#          s10 :     0 :  None :     1 : False :  True : Binary
#         s100 :     0 :  None :     1 : False :  True : Binary
#         s101 :     0 :  None :     1 : False :  True : Binary
#         s102 :     0 :  None :     1 : False :  True : Binary
#         s103 :     0 :  None :     1 : False :  True : Binary
#         s104 :     0 :  None :     1 : False :  True : Binary
#         s105 :     0 :  None :     1 : False :  True : Binary
#         s106 :     0 :  None :     1 : False :  True : Binary
#         s107 :     0 :  None :     1 : False :  True : Binary
#         s108 :     0 :  None :     1 : False :  True : Binary
#         s109 :     0 :  None :     1 : False :  True : Binary
#          s11 :     0 :  None :     1 : False :  True : Binary
#         s110 :     0 :  None :     1 : False :  True : Binary
#         s111 :     0 :  None :     1 : False :  True : Binary
#         s112 :     0 :  None :     1 : False :  True : Binary
#         s113 :     0 :  None :     1 : False :  True : Binary
#         s114 :     0 :  None :     1 : False :  True : Binary
#         s115 :     0 :  None :     1 : False :  True : Binary
#         s116 :     0 :  None :     1 : False :  True : Binary
#         s117 :     0 :  None :     1 : False :  True : Binary
#         s118 :     0 :  None :     1 : False :  True : Binary
#         s119 :     0 :  None :     1 : False :  True : Binary
#          s12 :     0 :  None :     1 : False :  True : Binary
#          s13 :     0 :  None :     1 : False :  True : Binary
#          s14 :     0 :  None :     1 : False :  True : Binary
#          s15 :     0 :  None :     1 : False :  True : Binary
#          s16 :     0 :  None :     1 : False :  True : Binary
#          s17 :     0 :  None :     1 : False :  True : Binary
#          s18 :     0 :  None :     1 : False :  True : Binary
#          s19 :     0 :  None :     1 : False :  True : Binary
#           s2 :     0 :  None :     1 : False :  True : Binary
#          s20 :     0 :  None :     1 : False :  True : Binary
#          s21 :     0 :  None :     1 : False :  True : Binary
#          s22 :     0 :  None :     1 : False :  True : Binary
#          s23 :     0 :  None :     1 : False :  True : Binary
#          s24 :     0 :  None :     1 : False :  True : Binary
#          s25 :     0 :  None :     1 : False :  True : Binary
#          s26 :     0 :  None :     1 : False :  True : Binary
#          s27 :     0 :  None :     1 : False :  True : Binary
#          s28 :     0 :  None :     1 : False :  True : Binary
#          s29 :     0 :  None :     1 : False :  True : Binary
#           s3 :     0 :  None :     1 : False :  True : Binary
#          s30 :     0 :  None :     1 : False :  True : Binary
#          s31 :     0 :  None :     1 : False :  True : Binary
#          s32 :     0 :  None :     1 : False :  True : Binary
#          s33 :     0 :  None :     1 : False :  True : Binary
#          s34 :     0 :  None :     1 : False :  True : Binary
#          s35 :     0 :  None :     1 : False :  True : Binary
#          s36 :     0 :  None :     1 : False :  True : Binary
#          s37 :     0 :  None :     1 : False :  True : Binary
#          s38 :     0 :  None :     1 : False :  True : Binary
#          s39 :     0 :  None :     1 : False :  True : Binary
#           s4 :     0 :  None :     1 : False :  True : Binary
#          s40 :     0 :  None :     1 : False :  True : Binary
#          s41 :     0 :  None :     1 : False :  True : Binary
#          s42 :     0 :  None :     1 : False :  True : Binary
#          s43 :     0 :  None :     1 : False :  True : Binary
#          s44 :     0 :  None :     1 : False :  True : Binary
#          s45 :     0 :  None :     1 : False :  True : Binary
#          s46 :     0 :  None :     1 : False :  True : Binary
#          s47 :     0 :  None :     1 : False :  True : Binary
#          s48 :     0 :  None :     1 : False :  True : Binary
#          s49 :     0 :  None :     1 : False :  True : Binary
#           s5 :     0 :  None :     1 : False :  True : Binary
#          s50 :     0 :  None :     1 : False :  True : Binary
#          s51 :     0 :  None :     1 : False :  True : Binary
#          s52 :     0 :  None :     1 : False :  True : Binary
#          s53 :     0 :  None :     1 : False :  True : Binary
#          s54 :     0 :  None :     1 : False :  True : Binary
#          s55 :     0 :  None :     1 : False :  True : Binary
#          s56 :     0 :  None :     1 : False :  True : Binary
#          s57 :     0 :  None :     1 : False :  True : Binary
#          s58 :     0 :  None :     1 : False :  True : Binary
#          s59 :     0 :  None :     1 : False :  True : Binary
#           s6 :     0 :  None :     1 : False :  True : Binary
#          s60 :     0 :  None :     1 : False :  True : Binary
#          s61 :     0 :  None :     1 : False :  True : Binary
#          s62 :     0 :  None :     1 : False :  True : Binary
#          s63 :     0 :  None :     1 : False :  True : Binary
#          s64 :     0 :  None :     1 : False :  True : Binary
#          s65 :     0 :  None :     1 : False :  True : Binary
#          s66 :     0 :  None :     1 : False :  True : Binary
#          s67 :     0 :  None :     1 : False :  True : Binary
#          s68 :     0 :  None :     1 : False :  True : Binary
#          s69 :     0 :  None :     1 : False :  True : Binary
#           s7 :     0 :  None :     1 : False :  True : Binary
#          s70 :     0 :  None :     1 : False :  True : Binary
#          s71 :     0 :  None :     1 : False :  True : Binary
#          s72 :     0 :  None :     1 : False :  True : Binary
#          s73 :     0 :  None :     1 : False :  True : Binary
#          s74 :     0 :  None :     1 : False :  True : Binary
#          s75 :     0 :  None :     1 : False :  True : Binary
#          s76 :     0 :  None :     1 : False :  True : Binary
#          s77 :     0 :  None :     1 : False :  True : Binary
#          s78 :     0 :  None :     1 : False :  True : Binary
#          s79 :     0 :  None :     1 : False :  True : Binary
#           s8 :     0 :  None :     1 : False :  True : Binary
#          s80 :     0 :  None :     1 : False :  True : Binary
#          s81 :     0 :  None :     1 : False :  True : Binary
#          s82 :     0 :  None :     1 : False :  True : Binary
#          s83 :     0 :  None :     1 : False :  True : Binary
#          s84 :     0 :  None :     1 : False :  True : Binary
#          s85 :     0 :  None :     1 : False :  True : Binary
#          s86 :     0 :  None :     1 : False :  True : Binary
#          s87 :     0 :  None :     1 : False :  True : Binary
#          s88 :     0 :  None :     1 : False :  True : Binary
#          s89 :     0 :  None :     1 : False :  True : Binary
#           s9 :     0 :  None :     1 : False :  True : Binary
#          s90 :     0 :  None :     1 : False :  True : Binary
#          s91 :     0 :  None :     1 : False :  True : Binary
#          s92 :     0 :  None :     1 : False :  True : Binary
#          s93 :     0 :  None :     1 : False :  True : Binary
#          s94 :     0 :  None :     1 : False :  True : Binary
#          s95 :     0 :  None :     1 : False :  True : Binary
#          s96 :     0 :  None :     1 : False :  True : Binary
#          s97 :     0 :  None :     1 : False :  True : Binary
#          s98 :     0 :  None :     1 : False :  True : Binary
#          s99 :     0 :  None :     1 : False :  True : Binary
#     LE : Size=8, Index=LE_index
#         Key       : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 'x1') :  None :  None :  None : False :  True :  Reals
#         (1, 'x2') :  None :  None :  None : False :  True :  Reals
#         (2, 'x1') :  None :  None :  None : False :  True :  Reals
#         (2, 'x2') :  None :  None :  None : False :  True :  Reals
#         (3, 'x1') :  None :  None :  None : False :  True :  Reals
#         (3, 'x2') :  None :  None :  None : False :  True :  Reals
#         (4, 'x1') :  None :  None :  None : False :  True :  Reals
#         (4, 'x2') :  None :  None :  None : False :  True :  Reals
#     Y : Size=32, Index=Y_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (1, 1, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (1, 2, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (1, 2, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (1, 3, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (1, 3, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (1, 4, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (1, 4, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (2, 1, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (2, 1, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (2, 2, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (2, 2, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (2, 3, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (2, 3, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (2, 4, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (2, 4, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (3, 1, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (3, 1, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (3, 2, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (3, 2, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (3, 3, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (3, 3, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (3, 4, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (3, 4, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (4, 1, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (4, 1, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (4, 2, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (4, 2, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (4, 3, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (4, 3, 'x2') :     0 :  None :     1 : False :  True : Binary
#         (4, 4, 'x1') :     0 :  None :     1 : False :  True : Binary
#         (4, 4, 'x2') :     0 :  None :     1 : False :  True : Binary
#     x : Size=8, Index=x_index
#         Key       : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 'x1') :  None :  None :  None : False :  True :  Reals
#         (1, 'x2') :  None :  None :  None : False :  True :  Reals
#         (2, 'x1') :  None :  None :  None : False :  True :  Reals
#         (2, 'x2') :  None :  None :  None : False :  True :  Reals
#         (3, 'x1') :  None :  None :  None : False :  True :  Reals
#         (3, 'x2') :  None :  None :  None : False :  True :  Reals
#         (4, 'x1') :  None :  None :  None : False :  True :  Reals
#         (4, 'x2') :  None :  None :  None : False :  True :  Reals
#
# 1 Objective Declarations
#     OBJ : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 
 'x1') :  -Inf : x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s109]) :   0.8531468531468531 :   True
#         (1, 's109', 'x2') :  -Inf : x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s109]) :   0.7058823529411765 :   True
#         (1, 's114', 'x1') :  -Inf : x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s114]) :   0.7132867132867133 :   True
#         (1, 's114', 'x2') :  -Inf : x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s114]) :  0.49411764705882355 :   True
#         (1, 's115', 'x1') :  -Inf : x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s115]) :   0.8531468531468531 :   True
#         (1, 's115', 'x2') :  -Inf : x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s115]) :    0.738235294117647 :   True
#         (1, 's117', 'x1') :  -Inf : x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s117]) :   0.7720279720279719 :   True
#         (1, 's117', 'x2') :  -Inf : x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s117]) :   0.7235294117647059 :   True
#          (1, 's14', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s14]) :    0.848951048951049 :   True
#          (1, 's14', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s14]) :   0.6794117647058823 :   True
#          (1, 's16', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s16]) :   0.5832167832167832 :   True
#          (1, 's16', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s16]) :  0.23529411764705876 :   True
#           (1, 's2', 'x1') :  -Inf :   x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s2]) :   0.8223776223776222 :   True
#           (1, 's2', 'x2') :  -Inf :   x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s2]) :   0.9205882352941176 :   True
#          (1, 's21', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s21]) :   0.6503496503496502 :   True
#          (1, 's21', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s21]) :    0.711764705882353 :   True
#          (1, 's23', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s23]) :   0.7762237762237763 :   True
#          (1, 's23', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s23]) :   0.6617647058823529 :   True
#          (1, 's24', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s24]) :   0.7104895104895104 :   True
#          (1, 's24', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s24]) :   0.6088235294117648 :   True
#          (1, 's27', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s27]) :   0.5622377622377621 :   True
#          (1, 's27', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s27]) :   0.3647058823529411 :   True
#          (1, 's30', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s30]) :   0.7944055944055943 :   True
#          (1, 's30', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s30]) :   0.9852941176470588 :   True
#          (1, 's38', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s38]) :   0.5622377622377621 :   True
#          (1, 's38', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s38]) :   0.6441176470588235 :   True
#          (1, 's39', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s39]) :   0.7230769230769232 :   True
#          (1, 's39', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s39]) :   0.6323529411764706 :   True
#          (1, 's46', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s46]) :   0.7398601398601399 :   True
#          (1, 's46', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s46]) :   0.5470588235294118 :   True
#          (1, 's48', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s48]) :   0.9874125874125876 :   True
#          (1, 's48', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s48]) :    0.688235294117647 :   True
#           (1, 's5', 'x1') :  -Inf :   x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s5]) :   0.7972027972027971 :   True
#           (1, 's5', 'x2') :  -Inf :   x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s5]) :   0.7294117647058823 :   True
#          (1, 's51', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s51]) :   0.7510489510489511 :   True
#          (1, 's51', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s51]) :    0.626470588235294 :   True
#          (1, 's57', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s57]) :   0.9818181818181819 :   True
#          (1, 's57', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s57]) :                  0.5 :   True
#           (1, 's6', 'x1') :  -Inf :   x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s6]) :   0.6363636363636362 :   True
#           (1, 's6', 'x2') :  -Inf :   x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s6]) :   0.8352941176470589 :   True
#          (1, 's62', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s62]) :   0.8377622377622378 :   True
#          (1, 's62', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s62]) :   0.7499999999999999 :   True
#          (1, 's64', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s64]) :   0.8825174825174826 :   True
#          (1, 's64', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s64]) :                  0.5 :   True
#          (1, 's66', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s66]) :   0.6993006993006992 :   True
#          (1, 's66', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s66]) :   0.5911764705882353 :   True
#           (1, 's7', 'x1') :  -Inf :   x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s7]) :   0.7188811188811188 :   True
#           (1, 's7', 'x2') :  -Inf :   x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s7]) :   0.6588235294117646 :   True
#          (1, 's71', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s71]) :   0.6713286713286712 :   True
#          (1, 's71', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s71]) :   0.5647058823529412 :   True
#          (1, 's74', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s74]) :   0.8755244755244755 :   True
#          (1, 's74', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s74]) :   0.7029411764705881 :   True
#          (1, 's76', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s76]) :    0.744055944055944 :   True
#          (1, 's76', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s76]) :   0.7058823529411765 :   True
#          (1, 's78', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s78]) :   0.7426573426573426 :   True
#          (1, 's78', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s78]) :   0.7823529411764706 :   True
#          (1, 's79', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s79]) :   0.5482517482517482 :   True
#          (1, 's79', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s79]) :    0.964705882352941 :   True
#          (1, 's80', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s80]) :   0.7720279720279719 :   True
#          (1, 's80', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s80]) :    0.688235294117647 :   True
#          (1, 's85', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s85]) :    0.697902097902098 :   True
#          (1, 's85', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s85]) :   0.6529411764705882 :   True
#          (1, 's86', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s86]) :   0.7860139860139861 :   True
#          (1, 's86', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s86]) :                 0.85 :   True
#          (1, 's87', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s87]) :   0.7594405594405593 :   True
#          (1, 's87', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s87]) :                 0.65 :   True
#          (1, 's88', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s88]) :   0.7230769230769232 :   True
#          (1, 's88', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s88]) :   0.5588235294117647 :   True
#          (1, 's89', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s89]) :   0.8391608391608392 :   True
#          (1, 's89', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s89]) :   0.6441176470588235 :   True
#           (1, 's9', 'x1') :  -Inf :   x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s9]) :   0.6881118881118882 :   True
#           (1, 's9', 'x2') :  -Inf :   x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s9]) :    0.526470588235294 :   True
#          (1, 's91', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s91]) :   0.5748251748251747 :   True
#          (1, 's91', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s91]) :   0.8882352941176471 :   True
#          (1, 's93', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s93]) :   0.7594405594405593 :   True
#          (1, 's93', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s93]) :   0.5352941176470588 :   True
#          (1, 's95', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s95]) :                  1.0 :   True
#          (1, 's95', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s95]) :  0.32352941176470584 :   True
#          (1, 's98', 'x1') :  -Inf :  x[1,x1] - 0.5*LE[1,x1] - 1.5*(1 - E[s98]) :   0.8531468531468531 :   True
#          (1, 's98', 'x2') :  -Inf :  x[1,x2] - 0.5*LE[1,x2] - 1.5*(1 - E[s98]) :    0.626470588235294 :   True
#         (2, 's100', 'x1') :  -Inf : x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s100]) :   0.0811188811188811 :   True
#         (2, 's100', 'x2') :  -Inf : x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s100]) :   0.5970588235294118 :   True
#         (2, 's103', 'x1') :  -Inf : x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s103]) :   0.1048951048951049 :   True
#         (2, 's103', 'x2') :  -Inf : x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s103]) :   0.9764705882352941 :   True
#         (2, 's119', 'x1') :  -Inf : x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s119]) :  0.16923076923076918 :   True
#         (2, 's119', 'x2') :  -Inf : x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s119]) :   0.7911764705882353 :   True
#          (2, 's17', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s17]) :  0.08531468531468528 :   True
#          (2, 's17', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s17]) :   0.8529411764705882 :   True
#          (2, 's28', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s28]) : 0.005594405594405577 :   True
#          (2, 's28', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s28]) :    0.738235294117647 :   True
#          (2, 's32', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s32]) :  0.13986013986013984 :   True
#          (2, 's32', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s32]) :   0.8382352941176471 :   True
#          (2, 's43', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s43]) :   0.1048951048951049 :   True
#          (2, 's43', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s43]) :   0.8558823529411764 :   True
#          (2, 's67', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s67]) :  0.15384615384615385 :   True
#          (2, 's67', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s67]) :   0.6999999999999998 :   True
#          (2, 's69', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s69]) :  0.06993006993006995 :   True
#          (2, 's69', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s69]) :    0.823529411764706 :   True
#          (2, 's70', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s70]) :  0.08671328671328671 :   True
#          (2, 's70', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s70]) :   0.9117647058823529 :   True
#          (2, 's90', 'x1') :  -Inf :  x[2,x1] - 0.5*LE[2,x1] - 1.5*(1 - E[s90]) :  0.03916083916083918 :   True
#          (2, 's90', 'x2') :  -Inf :  x[2,x2] - 0.5*LE[2,x2] - 1.5*(1 - E[s90]) :   0.8382352941176471 :   True
#          (3, 's35', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s35]) :   0.4209790209790209 :   True
#          (3, 's35', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s35]) :   0.6705882352941176 :   True
#          (3, 's47', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s47]) :   0.3174825174825175 :   True
#          (3, 's47', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s47]) :   0.8323529411764704 :   True
#          (3, 's55', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s55]) :   0.2839160839160839 :   True
#          (3, 's55', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s55]) :   0.7058823529411765 :   True
#          (3, 's56', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s56]) :   0.3468531468531469 :   True
#          (3, 's56', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s56]) :   0.7970588235294117 :   True
#          (3, 's59', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s59]) :   0.2993006993006993 :   True
#          (3, 's59', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s59]) :   0.8088235294117646 :   True
#          (3, 's61', 'x1') :  -Inf :  x[3,x1] - 0.5*LE[3,x1] - 1.5*(1 - E[s61]) :   0.2755244755244755 :   True
#          (3, 's61', 'x2') :  -Inf :  x[3,x2] - 0.5*LE[3,x2] - 1.5*(1 - E[s61]) :   0.7735294117647057 :   True
# ...
#         (4, 's102', 'x1') :   0.3328671328671328 : x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s102]) :  +Inf :   True
#         (4, 's102', 'x2') :  0.09999999999999998 : x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s102]) :  +Inf :   True
#         (4, 's104', 'x1') :   0.3678321678321678 : x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s104]) :  +Inf :   True
#         (4, 's104', 'x2') :  0.14411764705882346 : x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s104]) :  +Inf :   True
#         (4, 's106', 'x1') :  0.13286713286713286 : x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s106]) :  +Inf :   True
#         (4, 's106', 'x2') :   0.3735294117647058 : x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s106]) :  +Inf :   True
#         (4, 's108', 'x1') :  0.14685314685314688 : x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s108]) :  +Inf :   True
#         (4, 's108', 'x2') :  0.25588235294117645 : x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s108]) :  +Inf :   True
#          (4, 's11', 'x1') :  0.24895104895104897 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s11]) :  +Inf :   True
#          (4, 's11', 'x2') :  0.22941176470588232 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[
:  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s34]) :  +Inf :   True
#          (4, 's34', 'x2') : 0.002941176470588225 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s34]) :  +Inf :   True
#          (4, 's36', 'x1') :  0.29370629370629364 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s36]) :  +Inf :   True
#          (4, 's36', 'x2') :  0.04705882352941171 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s36]) :  +Inf :   True
#          (4, 's37', 'x1') :  0.31328671328671337 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s37]) :  +Inf :   True
#          (4, 's37', 'x2') :  0.04705882352941171 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s37]) :  +Inf :   True
#           (4, 's4', 'x1') :   0.2825174825174825 :   x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s4]) :  +Inf :   True
#           (4, 's4', 'x2') :   0.0676470588235294 :   x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s4]) :  +Inf :   True
#          (4, 's40', 'x1') :  0.24475524475524474 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s40]) :  +Inf :   True
#          (4, 's40', 'x2') :   0.3735294117647058 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s40]) :  +Inf :   True
#          (4, 's41', 'x1') :  0.22237762237762237 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s41]) :  +Inf :   True
#          (4, 's41', 'x2') : 0.035294117647058754 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s41]) :  +Inf :   True
#          (4, 's42', 'x1') :   0.3272727272727273 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s42]) :  +Inf :   True
#          (4, 's42', 'x2') :  0.39411764705882346 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s42]) :  +Inf :   True
#          (4, 's44', 'x1') :  0.27692307692307694 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s44]) :  +Inf :   True
#          (4, 's44', 'x2') : 0.029411764705882304 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s44]) :  +Inf :   True
#          (4, 's45', 'x1') :  0.15384615384615385 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s45]) :  +Inf :   True
#          (4, 's45', 'x2') :  0.39117647058823524 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s45]) :  +Inf :   True
#          (4, 's49', 'x1') :  0.16923076923076918 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s49]) :  +Inf :   True
#          (4, 's49', 'x2') :  0.00588235294117645 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s49]) :  +Inf :   True
#          (4, 's50', 'x1') :   0.1944055944055944 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s50]) :  +Inf :   True
#          (4, 's50', 'x2') :  0.05882352941176466 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s50]) :  +Inf :   True
#          (4, 's52', 'x1') :   0.2433566433566433 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s52]) :  +Inf :   True
#          (4, 's52', 'x2') :   0.3411764705882353 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s52]) :  +Inf :   True
#          (4, 's53', 'x1') :  0.19020979020979017 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s53]) :  +Inf :   True
#          (4, 's53', 'x2') :  0.30294117647058827 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s53]) :  +Inf :   True
#          (4, 's54', 'x1') :  0.15384615384615385 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s54]) :  +Inf :   True
#          (4, 's54', 'x2') :  0.09117647058823525 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s54]) :  +Inf :   True
#          (4, 's58', 'x1') :  0.25594405594405595 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s58]) :  +Inf :   True
#          (4, 's58', 'x2') :  0.34705882352941175 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s58]) :  +Inf :   True
#          (4, 's60', 'x1') :    0.393006993006993 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s60]) :  +Inf :   True
#          (4, 's60', 'x2') :  0.17352941176470582 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s60]) :  +Inf :   True
#          (4, 's63', 'x1') :   0.0811188811188811 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s63]) :  +Inf :   True
#          (4, 's63', 'x2') :  0.35882352941176465 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s63]) :  +Inf :   True
#          (4, 's68', 'x1') :  0.40559440559440557 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s68]) :  +Inf :   True
#          (4, 's68', 'x2') :  0.12058823529411761 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s68]) :  +Inf :   True
#          (4, 's72', 'x1') :  0.22797202797202798 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s72]) :  +Inf :   True
#          (4, 's72', 'x2') :  0.19999999999999996 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s72]) :  +Inf :   True
#          (4, 's73', 'x1') :  0.40559440559440557 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s73]) :  +Inf :   True
#          (4, 's73', 'x2') :  0.22941176470588232 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s73]) :  +Inf :   True
#          (4, 's75', 'x1') :  0.34825174825174826 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s75]) :  +Inf :   True
#          (4, 's75', 'x2') : 0.029411764705882304 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s75]) :  +Inf :   True
#           (4, 's8', 'x1') :  0.23636363636363633 :   x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s8]) :  +Inf :   True
#           (4, 's8', 'x2') :   0.4235294117647058 :   x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s8]) :  +Inf :   True
#          (4, 's81', 'x1') :  0.15524475524475523 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s81]) :  +Inf :   True
#          (4, 's81', 'x2') :  0.42647058823529405 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s81]) :  +Inf :   True
#          (4, 's82', 'x1') :   0.3734265734265734 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s82]) :  +Inf :   True
#          (4, 's82', 'x2') :   0.2147058823529412 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s82]) :  +Inf :   True
#          (4, 's83', 'x1') :   0.2797202797202797 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s83]) :  +Inf :   True
#          (4, 's83', 'x2') :  0.40588235294117647 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s83]) :  +Inf :   True
#          (4, 's84', 'x1') :  0.27832167832167837 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s84]) :  +Inf :   True
#          (4, 's84', 'x2') :   0.3735294117647058 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s84]) :  +Inf :   True
#          (4, 's92', 'x1') :  0.27272727272727265 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s92]) :  +Inf :   True
#          (4, 's92', 'x2') :                 0.35 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s92]) :  +Inf :   True
#          (4, 's94', 'x1') :  0.32027972027972035 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s94]) :  +Inf :   True
#          (4, 's94', 'x2') :   0.3676470588235293 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s94]) :  +Inf :   True
#          (4, 's96', 'x1') :   0.1944055944055944 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s96]) :  +Inf :   True
#          (4, 's96', 'x2') :                 0.35 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s96]) :  +Inf :   True
#          (4, 's97', 'x1') :    0.220979020979021 :  x[4,x1] + 0.5*LE[4,x1] + 1.5*(1 - E[s97]) :  +Inf :   True
#          (4, 's97', 'x2') :   0.3411764705882353 :  x[4,x2] + 0.5*LE[4,x2] + 1.5*(1 - E[s97]) :  +Inf :   True
#     eq3 : Size=24, Index=eq3_index, Active=True
#         Key          : Lower : Body                                                                    : Upper : Active
#         ('x1', 1, 2) :  -Inf : (LE[1,x1] + LE[2,x1])*0.5 + 0.001 - (x[1,x1] - x[2,x1] + 1.5*Y[1,2,x1]) :   0.0 :   True
#         ('x1', 1, 3) :  -Inf : (LE[1,x1] + LE[3,x1])*0.5 + 0.001 - (x[1,x1] - x[3,x1] + 1.5*Y[1,3,x1]) :   0.0 :   True
#         ('x1', 1, 4) :  -Inf : (LE[1,x1] + LE[4,x1])*0.5 + 0.001 - (x[1,x1] - x[4,x1] + 1.5*Y[1,4,x1]) :   0.0 :   True
#         ('x1', 2, 1) :  -Inf : (LE[2,x1] + LE[1,x1])*0.5 + 0.001 - (x[2,x1] - x[1,x1] + 1.5*Y[2,1,x1]) :   0.0 :   True
#         ('x1', 2, 3) :  -Inf : (LE[2,x1] + LE[3,x1])*0.5 + 0.001 - (x[2,x1] - x[3,x1] + 1.5*Y[2,3,x1]) :   0.0 :   True
#         ('x1', 2, 4) :  -Inf : (LE[2,x1] + LE[4,x1])*0.5 + 0.001 - (x[2,x1] - x[4,x1] + 1.5*Y[2,4,x1]) :   0.0 :   True
#         ('x1', 3, 1) :  -Inf : (LE[3,x1] + LE[1,x1])*0.5 + 0.001 - (x[3,x1] - x[1,x1] + 1.5*Y[3,1,x1]) :   0.0 :   True
#         ('x1', 3, 2) :  -Inf : (LE[3,x1] + LE[2,x1])*0.5 + 0.001 - (x[3,x1] - x[2,x1] + 1.5*Y[3,2,x1]) :   0.0 :   True
#         ('x1', 3, 4) :  -Inf : (LE[3,x1] + LE[4,x1])*0.5 + 0.001 - (x[3,x1] - x[4,x1] + 1.5*Y[3,4,x1]) :   0.0 :   True
#         ('x1', 4, 1) :  -Inf : (LE[4,x1] + LE[1,x1])*0.5 + 0.001 - (x[4,x1] - x[1,x1] + 1.5*Y[4,1,x1]) :   0.0 :   True
#         ('x1', 4, 2) :  -Inf : (LE[4,x1] + LE[2,x1])*0.5 + 0.001 - (x[4,x1] - x[2,x1] + 1.5*Y[4,2,x1]) :   0.0 :   True
#         ('x1', 4, 3) :  -Inf : (LE[4,x1] + LE[3,x1])*0.5 + 0.001 - (x[4,x1] - x[3,x1] + 1.5*Y[4,3,x1]) :   0.0 :   True
#         ('x2', 1, 2) :  -Inf : (LE[1,x2] + LE[2,x2])*0.5 + 0.001 - (x[1,x2] - x[2,x2] + 1.5*Y[1,2,x2]) :   0.0 :   True
#         ('x2', 1, 3) :  -Inf : (LE[1,x2] + LE[3,x2])*0.5 + 0.001 - (x[1,x2] - x[3,x2] + 1.5*Y[1,3,x2]) :   0.0 :   True
#         ('x2', 1, 4) :  -Inf : (LE[1,x2] + LE[4,x2])*0.5 + 0.001 - (x[1,x2] - x[4,x2] + 1.5*Y[1,4,x2]) :   0.0 :   True
#         ('x2', 2, 1) :  -Inf : (LE[2,x2] + LE[1,x2])*0.5 + 0.001 - (x[2,x2] - x[1,x2] + 1.5*Y[2,1,x2]) :   0.0 :   True
#         ('x2', 2, 3) :  -Inf : (LE[2,x2] + LE[3,x2])*0.5 + 0.001 - (x[2,x2] - x[3,x2] + 1.5*Y[2,3,x2]) :   0.0 :   True
#         ('x2', 2, 4) :  -Inf : (LE[2,x2] + LE[4,x2])*0.5 + 0.001 - (x[2,x2] - x[4,x2] + 1.5*Y[2,4,x2]) :   0.0 :   True
#         ('x2', 3, 1) :  -Inf : (LE[3,x2] + LE[1,x2])*0.5 + 0.001 - (x[3,x2] - x[1,x2] + 1.5*Y[3,1,x2]) :   0.0 :   True
#         ('x2', 3, 2) :  -Inf : (LE[3,x2] + LE[2,x2])*0.5 + 0.001 - (x[3,x2] - x[2,x2] + 1.5*Y[3,2,x2]) :   0.0 :   True
#         ('x2', 3, 4) :  -Inf : (LE[3,x2] + LE[4,x2])*0.5 + 0.001 - (x[3,x2] - x[4,x2] + 1.5*Y[3,4,x2]) :   0.0 :   True
#         ('x2', 4, 1) :  -Inf : (LE[4,x2] + LE[1,x2])*0.5 + 0.001 - (x[4,x2] - x[1,x2] + 1.5*Y[4,1,x2]) :   0.0 :   True
#         ('x2', 4, 2) :  -Inf : (LE[4,x2] + LE[2,x2])*0.5 + 0.001 - (x[4,x2] - x[2,x2] + 1.5*Y[4,2,x2]) :   0.0 :   True
#         ('x2', 4, 3) :  -Inf : (LE[4,x2] + LE[3,x2])*0.5 + 0.001 - (x[4,x2] - x[3,x2] + 1.5*Y[4,3,x2]) :   0.0 :   True
#     eq4 : Size=6, Index=eq4_index, Active=True
#         Key    : Lower : Body                                          : Upper : Active
#         (1, 2) :  -Inf : Y[1,2,x1] + Y[2,1,x1] + Y[1,2,x2] + Y[2,1,x2] :   3.0 :   True
#         (1, 3) :  -Inf : Y[1,3,x1] + Y[3,1,x1] + Y[1,3,x2] + Y[3,1,x2] :   3.0 :   True
#         (1, 4) :  -Inf : Y[1,4,x1] + Y[4,1,x1] + Y[1,4,x2] + Y[4,1,x2] :   3.0 :   True
#         (2, 3) :  -Inf : Y[2,3,x1] + Y[3,2,x1] + Y[2,3,x2] + Y[3,2,x2] :   3.0 :   True
#         (2, 4) :  -Inf : Y[2,4,x1] + Y[4,2,x1] + Y[2,4,x2] + Y[4,2,x2] :   3.0 :   True
#         (3, 4) :  -Inf : Y[3,4,x1] + Y[4,3,x1] + Y[3,4,x2] + Y[4,3,x2] :   3.0 :   True
#
# 29 Declarations: s m i j A_index A U map_index map x_index x LE_index LE E Y_index_index_0 Y_index Y OBJ eq1_index_index_0 eq1_index eq1 eq2_index_index_0 eq2_index eq2 eq3_index_index_0 eq3_index eq3 eq4_index eq4

# %%
for v in instance.component_objects(Var, active=True):
    print ("Variable component object",v)
    print ("Type of component object: ", str(type(v))[1:-1]) # Stripping <> for nbconvert
    varobject = getattr(instance, str(v))
    print ("Type of object accessed via getattr: ", str(type(varobject))[1:-1])
    for index in varobject:
        print ("   ", index, varobject[index].value)
# Out:
# Variable component object x
# Type of component object:  class 'pyomo.core.base.var.IndexedVar'
# Type of object accessed via getattr:  class 'pyomo.core.base.var.IndexedVar'
#     (1, 'x1') 0.7741258741258741
#     (1, 'x2') 0.6176470588235294
#     (2, 'x1') 0.08741258741258728
#     (2, 'x2') 0.7985294117647059
#     (3, 'x1') 0.3482517482517482
#     (3, 'x2') 0.8
#     (4, 'x1') 0.24685314685314674
#     (4, 'x2') -0.034794117647058864
# Variable component object LE
# Type of component object:  class 'pyomo.core.base.var.IndexedVar'
# Type of object accessed via getattr:  class 'pyomo.core.base.var.IndexedVar'
#     (1, 'x1') 0.45174825174825184
#     (1, 'x2') 0.7647058823529411
#     (2, 'x1') 0.16363636363636358
#     (2, 'x2') 0.40294117647058814
#     (3, 'x1') 0.1454545454545455
#     (3, 'x2') 0.3999999999999998
#     (4, 'x1') 0.3314685314685315
#     (4, 'x2') 0.9284117647058825
# Variable component object E
# Type of component object:  class 'pyomo.core.base.var.IndexedVar'
# Type of object accessed via getattr:  class 'pyomo.core.base.var.IndexedVar'
#     s1 1.0
#     s2 1.0
#     s3 1.0
#     s4 1.0
#     s5 1.0
#     s6 1.0
#     s7 1.0
#     s8 1.0
#     s9 1.0
#     s10 1.0
#     s11 1.0
#     s12 1.0
#     s13 1.0
#     s14 1.0
#     s15 1.0
#     s16 1.0
#     s17 1.0
#     s18 1.0
#     s19 1.0
#     s20 1.0
#     s21 1.0
#     s22 1.0
#     s23 1.0
#     s24 1.0
#     s25 1.0
#     s26 1.0
#     s27 1.0
#     s28 1.0
#     s29 1.0
#     s30 1.0
#     s31 1.0
#     s32 1.0
#     s33 1.0
#     s34 1.0
#     s35 1.0
#     s36 1.0
#     s37 1.0
#     s38 1.0
#     s39 1.0
#     s40 1.0
#     s41 1.0
#     s42 1.0
#     s43 1.0
#     s44 1.0
#     s45 1.0
#     s46 1.0
#     s47 1.0
#     s48 1.0
#     s49 1.0
#     s50 1.0
#     s51 1.0
#     s52 1.0
#     s53 1.0
#     s54 1.0
#     s55 1.0
#     s56 1.0
#     s57 1.0
#     s58 1.0
#     s59 1.0
#     s60 1.0
#     s61 1.0
#     s62 1.0
#     s63 1.0
#     s64 1.0
#     s65 1.0
#     s66 1.0
#     s67 1.0
#     s68 1.0
#     s69 1.0
#     s70 1.0
#     s71 1.0
#     s72 1.0
#     s73 1.0
#     s74 1.0
#     s75 1.0
#     s76 1.0
#     s77 1.0
#     s78 1.0
#     s79 1.0
#     s80 1.0
#     s81 1.0
#     s82 1.0
#     s83 1.0
#     s84 1.0
#     s85 1.0
#     s86 1.0
#     s87 1.0
#     s88 1.0
#     s89 1.0
#     s90 1.0
#     s91 1.0
#     s92 1.0
#     s93 1.0
#     s94 1.0
#     s95 1.0
#     s96 1.0
#     s97 1.0
#     s98 1.0
#     s99 1.0
#     s100 1.0
#     s101 1.0
#     s102 1.0
#     s103 1.0
#     s104 1.0
#     s105 1.0
#     s106 1.0
#     s107 1.0
#     s108 1.0
#     s109 1.0
#     s110 1.0
#     s111 1.0
#     s112 1.0
#     s113 1.0
#     s114 1.0
#     s115 1.0
#     s116 1.0
#     s117 1.0
#     s118 1.0
#     s119 1.0
# Variable component object Y
# Type of component object:  class 'pyomo.core.base.var.IndexedVar'
# Type of object accessed via getattr:  class 'pyomo.core.base.var.IndexedVar'
#     (1, 1, 'x1') None
#     (1, 1, 'x2') None
#     (1, 2, 'x1') 0.0
#     (1, 2, 'x2') 1.0
#     (1, 3, 'x1') 0.0
#     (1, 3, 'x2') 1.0
#     (1, 4, 'x1') 0.0
#     (1, 4, 'x2') 1.0
#     (2, 1, 'x1') 1.0
#     (2, 1, 'x2') 1.0
#     (2, 2, 'x1') None
#     (2, 2, 'x2') None
#     (2, 3, 'x1') 1.0
#     (2, 3, 'x2') 1.0
#     (2, 4, 'x1') 1.0
#     (2, 4, 'x2') 0.0
#     (3, 1, 'x1') 1.0
#     (3, 1, 'x2') 1.0
#     (3, 2, 'x1') 0.0
#     (3, 2, 'x2') 1.0
#     (3, 3, 'x1') None
#     (3, 3, 'x2') None
#     (3, 4, 'x1') 1.0
#     (3, 4, 'x2') 0.0
#     (4, 1, 'x1') 1.0
#     (4, 1, 'x2') 1.0
#     (4, 2, 'x1') 1.0
#     (4, 2, 'x2') 1.0
#     (4, 3, 'x1') 1.0
#     (4, 3, 'x2') 1.0
#     (4, 4, 'x1') None
#     (4, 4, 'x2') None
